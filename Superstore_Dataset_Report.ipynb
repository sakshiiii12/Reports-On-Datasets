# %% [markdown]
# # Title: Global Superstore Sales Analysis

# %%
#Import the important library's

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the dataset samplesuperstore.csv

# %%
df = pd.read_csv("c:/users/sakshi yadav/Downloads/Sample - Superstore.csv/Sample - Superstore.csv", encoding='latin')

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
#Checking the duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Checking the null values 
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
#Convert the order data and ship data columns to datetime format

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
#Exploratory Data Analysis

# %%
#Total Sales and Total Profit
total_sales = df['Sales'].sum()

# %%
total_profit = df['Profit'].sum()

# %%
print("Total_Sales:",total_sales)
# Out:
# Total_Sales: 2297200.8603000003

# %%
print("Total_Profit:",total_profit)
# Out:
# Total_Profit: 286397.0217

# %%
#Top 10 Profitable Products
profitable_products = df.groupby('Product Name')['Profit'].sum().sort_values(ascending=True).head(10)

# %%
profitable_products.reset_index()
# Out:
#                                         Product Name     Profit
# 0          Cubify CubeX 3D Printer Double Head Print -8879.9704
# 1          Lexmark MX611dhe Monochrome Laser Printer -4589.9730
# 2          Cubify CubeX 3D Printer Triple Head Print -3839.9904
# 3  Chromcraft Bull-Nose Wood Oval Conference Tabl... -2876.1156
# 4  Bush Advantage Collection Racetrack Conference... -1934.3976
# 5          GBC DocuBind P400 Electric Binding System -1878.1662
# 6  Cisco TelePresence System EX90 Videoconferenci... -1811.0784
# 7  Martin Yale Chadless Opener Electric Letter Op... -1299.1836
# 8                       Balt Solid Wood Round Tables -1201.0581
# 9  BoxOffice By Design Rectangular and Half-Moon ... -1148.4375

# %%
#Sales Vs Profit By Region and State
region_state = df.groupby(['Region', 'State'])[['Sales', 'Profit']].sum().reset_index()

# %%
region_state.head(10)
# Out:
#     Region         State      Sales      Profit
# 0  Central      Illinois  80166.101 -12607.8870
# 1  Central       Indiana  53555.360  18382.9363
# 2  Central          Iowa   4579.760   1183.8119
# 3  Central        Kansas   2914.310    836.4435
# 4  Central      Michigan  76269.614  24463.1876
# 5  Central     Minnesota  29863.150  10823.1874
# 6  Central      Missouri  22205.150   6436.2105
# 7  Central      Nebraska   7464.930   2037.0942
# 8  Central  North Dakota    919.910    230.1497
# 9  Central      Oklahoma  19683.390   4853.9560

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
#Category & sub-category-wise performance.
cat_perform = df.groupby(['Category'])[['Sales', 'Profit']].sum()

# %%
cat_perform.reset_index()
# Out:
#           Category        Sales       Profit
# 0        Furniture  741999.7953   18451.2728
# 1  Office Supplies  719047.0320  122490.8008
# 2       Technology  836154.0330  145454.9481

# %%
sub_perform = df.groupby(['Sub-Category'])[['Sales', 'Profit']].sum()

# %%
sub_perform.reset_index()
# Out:
#    Sub-Category        Sales      Profit
# 0   Accessories  167380.3180  41936.6357
# 1    Appliances  107532.1610  18138.0054
# 2           Art   27118.7920   6527.7870
# 3       Binders  203412.7330  30221.7633
# 4     Bookcases  114879.9963  -3472.5560
# 5        Chairs  328449.1030  26590.1663
# 6       Copiers  149528.0300  55617.8249
# 7     Envelopes   16476.4020   6964.1767
# 8     Fasteners    3024.2800    949.5182
# 9   Furnishings   91705.1640  13059.1436
# 10       Labels   12486.3120   5546.2540
# 11     Machines  189238.6310   3384.7569
# 12        Paper   78479.2060  34053.5693
# 13       Phones  330007.0540  44515.7306
# 14      Storage  223843.6080  21278.8264
# 15     Supplies   46673.5380  -1189.0995
# 16       Tables  206965.5320 -17725.4811

# %%
#Delivery delay analysis: difference between Ship Date and Order Date.
df['delay_delivery'] = df['Ship Date'] - df['Order Date']

# %%
df['delay_delivery'].reset_index()
# Out:
#       index delay_delivery
# 0         0         3 days
# 1         1         3 days
# 2         2         4 days
# 3         3         7 days
# 4         4         7 days
# ...     ...            ...
# 9989   9989         2 days
# 9990   9990         5 days
# 9991   9991         5 days
# 9992   9992         5 days
# 9993   9993         5 days
#
# [9994 rows x 2 columns]

# %%
df.head(5)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
#Data Visulizations

# %%
#📈 Line chart: Monthly sales trend.
df['Year-Month'] = df['Order Date'].dt.to_period('M').astype(str)

# %%
monthly_sales = df.groupby('Year-Month')['Sales'].sum().reset_index()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly_sales, x='Year-Month', y='Sales', marker='o', color='red')
plt.title("Monthly Sales Trend")
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True)
plt.show()

# %%
#📊 Bar plots: Top states by profit and loss.
state_profit = df.groupby('State')['Profit'].sum().reset_index()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=state_profit, x='State', y='Profit', color='pink')
plt.title("Top States By Profit and Loss Trends")
plt.xlabel("State")
plt.ylabel("Profit")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
#📉 Scatter plot: Sales vs Profit.
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Sales', y='Profit', hue='Category')
plt.title('Sales vs Profit by Category')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'delay_delivery', 'Year-Month'],
#       dtype='object')

# %%
#📦 Count plot: Orders by shipping mode.
sns.countplot(x= 'Ship Mode', data=df, palette='pastel')
plt.title('Number of Orders by Shipping Mode')
plt.xlabel('Shipping Mode')
plt.ylabel('Order Count')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Sakshi Yadav\AppData\Local\Temp\ipykernel_17792\3835341811.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x= 'Ship Mode', data=df, palette='pastel')

# %%
#🌡 Heatmap: Profit by Region vs Category.
region_category_profit = df.groupby(['Region', 'Category'])['Profit'].sum().reset_index()

# %%
heatmap_data = region_category_profit.pivot(index='Region', columns='Category', values='Profit')

# %%
sns.heatmap(heatmap_data, annot=True, fmt=".0f", cmap="YlGnBu")
plt.title('Profit by Region and Category')
plt.xlabel('Category')
plt.ylabel('Region')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Project Completed!!!!!!!!
