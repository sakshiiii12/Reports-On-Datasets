# %% [markdown]
# # Featuring Enginerring And EDA On Test Dataset:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('c:/users/sakshi yadav/downloads/test.csv',encoding='latin')
df.head(3)
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN

# %%
df.shape
# Out:
# (233599, 11)

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2             72344
# Product_Category_3            162562
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233599 entries, 0 to 233598
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     233599 non-null  int64
#  1   Product_ID                  233599 non-null  object
#  2   Gender                      233599 non-null  object
#  3   Age                         233599 non-null  object
#  4   Occupation                  233599 non-null  int64
#  5   City_Category               233599 non-null  object
#  6   Stay_In_Current_City_Years  233599 non-null  object
#  7   Marital_Status              233599 non-null  int64
#  8   Product_Category_1          233599 non-null  int64
#  9   Product_Category_2          161255 non-null  float64
#  10  Product_Category_3          71037 non-null   float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 19.6+ MB

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3'],
#       dtype='object')

# %%
df['Product_Category_2'].unique()
# Out:
# array([11.,  5., 14.,  9.,  3.,  4., 13.,  2., nan,  8., 15., 17., 12.,
#        16.,  6., 10., 18.,  7.])

# %%
df['Product_Category_3'].unique()
# Out:
# array([nan, 12., 15.,  9., 16., 14.,  4.,  3.,  5.,  8., 17., 13., 11.,
#        10.,  6., 18.])

# %%
df['Product_Category_2'].mode()
# Out:
# 0    8.0
# Name: Product_Category_2, dtype: float64

# %%
df['Product_Category_3'].mode()
# Out:
# 0    16.0
# Name: Product_Category_3, dtype: float64

# %%
#Removing Null Values From Float64 DataType by filling mode values

# %%
for col in df.select_dtypes(include='float64').columns:
     df[col] = df[col].fillna(value=df[col].mode()[0])

# %%
df.select_dtypes(include='float64').isnull().sum()
# Out:
# Product_Category_2    0
# Product_Category_3    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3'],
#       dtype='object')

# %%
#Gender Distribution
sns.countplot(x='Gender',data=df, palette='magma')
plt.title('Gender Distribution')
plt.show()
# Out:
# C:\Users\Sakshi Yadav\AppData\Local\Temp\ipykernel_6352\1600048147.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender',data=df, palette='magma')

# %%
#Age Group Distribution
sns.countplot(x='Age',data=df, palette='viridis')
plt.title('Age Group Distribution')
plt.show()
# Out:
# C:\Users\Sakshi Yadav\AppData\Local\Temp\ipykernel_6352\3067778998.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Age',data=df, palette='viridis')

# %%
#Occupation Vs Number of users
sns.countplot(x='Occupation',data=df, palette='magma')
plt.title('Users by Occupation')
plt.show()
# Out:
# C:\Users\Sakshi Yadav\AppData\Local\Temp\ipykernel_6352\3364272425.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Occupation',data=df, palette='magma')

# %%
#City category
sns.countplot(x='City_Category', data=df, palette='pastel')
plt.title('City Category')
plt.show()
# Out:
# C:\Users\Sakshi Yadav\AppData\Local\Temp\ipykernel_6352\969125135.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='City_Category', data=df, palette='pastel')

# %%
#Stay Duration Vs City Category
sns.countplot(x='Stay_In_Current_City_Years', data=df, hue='City_Category',palette='magma')
plt.title('Stay Duration Vs City Category')
plt.show()

# %%
product_category = df.Product_Category_1.value_counts().index

# %%
product_category
# Out:
# Index([5, 1, 8, 2, 11, 6, 3, 4, 16, 15, 13, 10, 12, 7, 18, 14, 17, 9], dtype='int64', name='Product_Category_1')

# %%
product_val = df.Product_Category_1.value_counts().values

# %%
product_val
# Out:
# array([65017, 60321, 48369, 10192, 10153,  8860,  8578,  5003,  4105,
#         2694,  2381,  2248,  1663,  1624,  1311,   663,   223,   194])

# %%
#Top 10 most purchased product categories
plt.pie(product_val[:10],labels=product_category[:10],autopct='%1.2f%%')
plt.title('Top 10 Most Purchased Product Categories')
plt.show()

# %%
#Product preference by gender
sns.barplot(x='Gender',y='Product_Category_1',data=df, palette='magma')
plt.title('Product Category Preference by Gender')
plt.show()
# Out:
# C:\Users\Sakshi Yadav\AppData\Local\Temp\ipykernel_6352\690830070.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Gender',y='Product_Category_1',data=df, palette='magma')

# %%
category_count = df[['Product_Category_1', 'Product_Category_2', 'Product_Category_3']].count()

# %%
color=['blue', 'orange', 'green']
plt.pie(category_count, labels=category_count.index, autopct='%1.1f%%',colors=colors)
plt.title('Proportion of Purchases Across Categories')
plt.show()

# %%
sns.barplot(x='Occupation',y='Product_Category_1',data=df, palette='magma')
plt.title('Occupation vs. Product Preferences')
plt.show()
# Out:
# C:\Users\Sakshi Yadav\AppData\Local\Temp\ipykernel_6352\3803216665.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Occupation',y='Product_Category_1',data=df, palette='magma')

# %%
sns.barplot(x='City_Category', y='Product_Category_1', data=df, palette='cool')
plt.title('City-wise Spending Distribution')
plt.show()
# Out:
# C:\Users\Sakshi Yadav\AppData\Local\Temp\ipykernel_6352\387240902.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='City_Category', y='Product_Category_1', data=df, palette='cool')

# %%
sns.barplot(x='Marital_Status', y='Product_Category_1', data=df, palette='cool')
plt.title('Marital Status vs. Product Purchases')
plt.show()
# Out:
# C:\Users\Sakshi Yadav\AppData\Local\Temp\ipykernel_6352\3621307056.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Marital_Status', y='Product_Category_1', data=df, palette='cool')

# %% [markdown]
# # Project Finish!!!!!
